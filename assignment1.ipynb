# %% [markdown]
# Question--1(a)

# %%
L =[11,12,13,14]
L.append(50)
L.append(60)
print("after-->",L)
# Out:
# after--> [11, 12, 13, 14, 50, 60]

# %% [markdown]
# Question--1(b)

# %%
L =[11,12,13,14]
L.remove(11)
L.remove(13)
print(L)
# Out:
# [12, 14]

# %% [markdown]
# Question--1(c)

# %%
L =[11,12,13,14]
L.sort()
print(L)
# Out:
# [11, 12, 13, 14]

# %% [markdown]
# Question--1(d)

# %%
L =[11,12,13,14]
L.sort(reverse=True)
print(L)
# Out:
# [14, 13, 12, 11]

# %% [markdown]
# Question--1(e)

# %%
L =[11,12,13,14]

print(13 in L)
# Out:
# True

# %% [markdown]
# Question--1(f)

# %%
L =[11,12,13,14]

print(len(L))
# Out:
# 4

# %% [markdown]
# Question--1(g)

# %%
L =[11,12,13,14]

print(sum(L))
# Out:
# 50

# %% [markdown]
# Question--1(h)

# %%
L =[11,12,13,14]
total=0
for i in L:
 
 if not i % 2 == 0:
  total+=i  
print(total)
# Out:
# 24

# %% [markdown]
# Question--1(i)

# %%
L =[11,12,13,14]
total=0
for i in L:
 
 if  i % 2 == 0:
  total+=i  
print(total)
# Out:
# 26

# %% [markdown]
# Question--1(j)

# %%
L =[11,12,13,14]
def is_prime(num):
 for i in range(2, num//2 +1):
    if num % i == 0:
      return False
    else:
      return True

total = 0

for i in L:
  if is_prime(i):
    total += i

print(total)
# Out:
# 24

# %% [markdown]
# Question--1(k)

# %%
L =[11,12,13,14]
L.clear()
print(L)
# Out:
# []

# %% [markdown]
# Question--1(l)

# %%
L =[11,12,13,14]
del L 
print(L)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c2ed73d45300> in <cell line: 3>()
#       1 L =[11,12,13,14]
#       2 del L
# ----> 3 print(L)
#
# NameError: name 'L' is not defined

# %% [markdown]
# Question--2(a)

# %%
D= {1:5.6, 2:7.8, 3:6.6, 4:8.7, 5:7.7}
D[8] = 8.8
print(D)
# Out:
# {1: 5.6, 2: 7.8, 3: 6.6, 4: 8.7, 5: 7.7, 8: 8.8}

# %% [markdown]
# Question--2(b)

# %%
D= {1:5.6, 2:7.8, 3:6.6, 4:8.7, 5:7.7}
del D[2]
print(D)
# Out:
# {1: 5.6, 3: 6.6, 4: 8.7, 5: 7.7}

# %% [markdown]
# Question--2(c)

# %%
D= {1:5.6, 2:7.8, 3:6.6, 4:8.7, 5:7.7}
print(6 in D)
# Out:
# False

# %% [markdown]
# Question--2(d)

# %%
D= {1:5.6, 2:7.8, 3:6.6, 4:8.7, 5:7.7}
print(len(D))
# Out:
# 5

# %% [markdown]
# Question--2(e)

# %%
D= {1:5.6, 2:7.8, 3:6.6, 4:8.7, 5:7.7}
sum=0
for i in D.values():
 sum+=i
print(sum)
# Out:
# 36.4

# %% [markdown]
# Question--2(f)

# %%
D= {1:5.6, 2:7.8, 3:6.6, 4:8.7, 5:7.7}
D[3] = 7.1
print(D)
# Out:
# {1: 5.6, 2: 7.8, 3: 7.1, 4: 8.7, 5: 7.7}

# %% [markdown]
# Question--2(g)

# %%
D= {1:5.6, 2:7.8, 3:6.6, 4:8.7, 5:7.7}
D.clear()
print(D)
# Out:
# {}

# %% [markdown]
# Question--3(a)

# %%
 S1= set([10, 20, 30, 40, 50, 60])
 S2= set([40, 50, 60, 70, 80, 90])
 S1.add(55)
 S1.add(66)
 print(S1)
# Out:
# {66, 40, 10, 50, 20, 55, 60, 30}

# %% [markdown]
# Question--3(b)

# %%
 S1= set([10, 20, 30, 40, 50, 60])
 S2= set([40, 50, 60, 70, 80, 90])
 S1.remove(10)
 S1.remove(30)
 print(S1)
# Out:
# {40, 50, 20, 60}

# %% [markdown]
# Question--3(c)

# %%
 S1= set([10, 20, 30, 40, 50, 60])
 S2= set([40, 50, 60, 70, 80, 90])
 print(40 in S1)
# Out:
# True

# %% [markdown]
# Question--3(d)

# %%
 S1= set([10, 20, 30, 40, 50, 60])
 S2= set([40, 50, 60, 70, 80, 90])

 print(S1.union(S2))
# Out:
# {70, 40, 10, 80, 50, 20, 90, 60, 30}

# %% [markdown]
# Question--3(e)

# %%
 S1= set([10, 20, 30, 40, 50, 60])
 S2= set([40, 50, 60, 70, 80, 90])

 print(S1.intersection(S2))
# Out:
# {40, 50, 60}

# %% [markdown]
# Question--3(f)

# %%
S1= set([10, 20, 30, 40, 50, 60])
S2= set([40, 50, 60, 70, 80, 90])
S3 = S1 - S2 
print(S3)
# Out:
# {10, 20, 30}

# %% [markdown]
# Question--4(a)

# %%
import random
import string

def generate_random_string(length):
    return ''.join(random.choice(string.ascii_letters) for i in range(length))

for i in range(100):
    string_length = random.randint(6,8)
    random_string = generate_random_string(string_length)
    print(random_string)
# Out:
# XZvmrpsv
# BwfQNTG
# NIwOhHY
# dEIeGVd
# mvJZZobo
# fVlprY
# ZWoIqJ
# psuBRxb
# YNpNUWr
# zUYXBt
# FXzKJEPV
# wsEVkqNm
# VCUZvbC
# ycKeuuac
# XkJnBww
# UHHOCcd
# OitxnpaN
# cDjlyBH
# sMNMHUZo
# cCgUexcd
# zqeIdt
# HGSYiCcT
# QmPmfjmQ
# GykCIgcb
# EIdoNUK
# OHNaLlL
# toYbdJXX
# Paerki
# nOlSZw
# ZiphHO
# FAlnozoE
# GJryGJW
# giRDDfP
# OQFAKtix
# nrlBrts
# qbgqgMnT
# IsyueZ
# ZhilBdQA
# HzjVbuX
# klvxZp
# oztPOgvw
# GmlBXSTk
# BNrTMXZi
# IRPEJf
# DMAJhxwt
# NmydvlC
# LfHLZYE
# VAdEgja
# KbFmyn
# sSxvQcTw
# IzmwrcT
# IcgTbIgZ
# eaxJwDzU
# XRLvsd
# fiiWaQ
# jeDeBjUO
# SGDMQcJL
# VYSKfpfr
# kAavkbon
# DYmKje
# rQBiTMGK
# BqbYUc
# LRMHfng
# iiFYlSSO
# OfRrAYT
# sswcrFa
# uOoZXyn
# bhJOCVy
# AyGHTc
# rnjgCDpM
# IeztQGux
# NRYhiW
# rPJVPTrP
# XRZIsTgr
# QbyNYoQd
# EseBVG
# SwhIuBC
# jqdyXHx
# NrdUjAT
# xqITSYzR
# haFdfGA
# fiXCpBXE
# CGKTxT
# KlgBGu
# YjSnUC
# XqWPHn
# SBoIta
# MEpHHOCo
# IcBYbX
# QbfVjYau
# yUaEelE
# bejzwPs
# tRwGRY
# sNBzKn
# LOERWZ
# GdEKUN
# uFzYpuQJ
# wBLUhxwX
# crXVWRx
# ZNWFdWXt

# %% [markdown]
# Question--4(b)

# %%
def is_prime(num):
  for i in range(2, num//2 +1):
    if num % i == 0:
      return False
    else:
      return True

for i in range(600, 801):
  if is_prime(i):
    print(i)
# Out:
# 601
# 603
# 605
# 607
# 609
# 611
# 613
# 615
# 617
# 619
# 621
# 623
# 625
# 627
# 629
# 631
# 633
# 635
# 637
# 639
# 641
# 643
# 645
# 647
# 649
# 651
# 653
# 655
# 657
# 659
# 661
# 663
# 665
# 667
# 669
# 671
# 673
# 675
# 677
# 679
# 681
# 683
# 685
# 687
# 689
# 691
# 693
# 695
# 697
# 699
# 701
# 703
# 705
# 707
# 709
# 711
# 713
# 715
# 717
# 719
# 721
# 723
# 725
# 727
# 729
# 731
# 733
# 735
# 737
# 739
# 741
# 743
# 745
# 747
# 749
# 751
# 753
# 755
# 757
# 759
# 761
# 763
# 765
# 767
# 769
# 771
# 773
# 775
# 777
# 779
# 781
# 783
# 785
# 787
# 789
# 791
# 793
# 795
# 797
# 799

# %% [markdown]
# Question--4(c)

# %%
def is_divisible(num):
  if num % 7 == 0 and num % 9 == 0:
    return True
  else:
    return False

for i in range(100, 1001):
  if is_divisible(i):
    print(i)
# Out:
# 126
# 189
# 252
# 315
# 378
# 441
# 504
# 567
# 630
# 693
# 756
# 819
# 882
# 945

# %%
import random

def generate_random_numbers():
    return [random.randint(10, 30) for _ in range(10)]

list1 = generate_random_numbers()
list2 = generate_random_numbers()

print("List 1:", list1)
print("List 2:", list2)

# Find common numbers
common_numbers = set(list1).intersection(list2)
print("Common numbers:", common_numbers)

# Find unique numbers
unique_numbers = set(list1).symmetric_difference(list2)
print("Unique numbers:", unique_numbers)

# Find minimum values
min_value = min(min(list1), min(list2))
print("Minimum value:", min_value)

# Find maximum values
max_value = max(max(list1), max(list2))
print("Maximum value:", max_value)

# Find sum of both lists
total_sum = sum(list1) + sum(list2)
print("Sum of both lists:", total_sum)
# Out:
# List 1: [20, 10, 10, 26, 12, 20, 18, 17, 24, 29]
# List 2: [12, 24, 16, 15, 11, 22, 21, 12, 21, 22]
# Common numbers: {24, 12}
# Unique numbers: {10, 11, 15, 16, 17, 18, 20, 21, 22, 26, 29}
# Minimum value: 10
# Maximum value: 29
# Sum of both lists: 362

# %%
import random

def random_number_generator():
  return [random.randint(100,900) for i in range(100)]
odd = 0
odd_num = []
even = 0
even_num = []
prime = 0
prime_num = []
L = random_number_generator()
print(L)

# all odd numbers
print("Printing all Odd numbers in the list")
def is_odd(num):
  if num%2 == 0:
    return False
  else:
    return True

for i in L:
  if is_odd(i):
    odd_num.append(i)
    odd += 1

print(odd_num)
print("Odd numbers: ", odd)

# all even numbers
print("Printing all Even numbers in the list")
for i in L:
  if not is_odd(i):
    even_num.append(i)
    even += 1

print(even_num)
print("Even numbers: ", even)

# all prime numbers
print("Printing all Prime numbers in the list")
def is_prime(num):
  for i in range(2, num//2 +1):
    if num % i == 0:
      return False
    else:
      return True

for i in L:
  if is_prime(i):
    prime += 1
    prime_num.append(i)
print(prime_num)
print("Prime numbers are ", prime)
# Out:
# [858, 778, 866, 801, 831, 858, 341, 526, 853, 120, 732, 176, 100, 678, 561, 729, 517, 441, 685, 389, 702, 261, 344, 214, 235, 231, 527, 733, 688, 427, 448, 191, 143, 603, 553, 890, 379, 609, 539, 515, 434, 417, 828, 419, 572, 839, 345, 742, 177, 302, 870, 621, 220, 336, 481, 690, 877, 213, 333, 819, 763, 574, 175, 469, 536, 667, 670, 302, 386, 361, 231, 744, 888, 885, 714, 894, 895, 365, 719, 222, 830, 125, 362, 844, 246, 167, 479, 397, 521, 321, 401, 447, 652, 531, 769, 165, 778, 566, 581, 382]
# Printing all Odd numbers in the list
# [801, 831, 341, 853, 561, 729, 517, 441, 685, 389, 261, 235, 231, 527, 733, 427, 191, 143, 603, 553, 379, 609, 539, 515, 417, 419, 839, 345, 177, 621, 481, 877, 213, 333, 819, 763, 175, 469, 667, 361, 231, 885, 895, 365, 719, 125, 167, 479, 397, 521, 321, 401, 447, 531, 769, 165, 581]
# Odd numbers:  57
# Printing all Even numbers in the list
# [858, 778, 866, 858, 526, 120, 732, 176, 100, 678, 702, 344, 214, 688, 448, 890, 434, 828, 572, 742, 302, 870, 220, 336, 690, 574, 536, 670, 302, 386, 744, 888, 714, 894, 222, 830, 362, 844, 246, 652, 778, 566, 382]
# Even numbers:  43
# Printing all Prime numbers in the list
# [801, 831, 341, 853, 561, 729, 517, 441, 685, 389, 261, 235, 231, 527, 733, 427, 191, 143, 603, 553, 379, 609, 539, 515, 417, 419, 839, 345, 177, 621, 481, 877, 213, 333, 819, 763, 175, 469, 667, 361, 231, 885, 895, 365, 719, 125, 167, 479, 397, 521, 321, 401, 447, 531, 769, 165, 581]
# Prime numbers are  57

# %%
D = {1: "One", 2: "Two", 3: "Three", 4: "Four", 5: "Five"}

with open("output7.txt", "w") as file:
    for key, value in D.items():
        file.write(f"{key}, {value}\n")

# %%
L = ["One", "Two", "Three", "Four", "Five"]

with open("output8.txt", "w") as file:
    for element in L:
        length = len(element)
        file.write(f"{element}, {length}\n")

# %%
import random
import string

def generate_random_string(length):
    return ''.join(random.choice(string.ascii_letters) for _ in range(length))

with open("output9.txt", "w") as file:
    for _ in range(100):
        string_length = random.randint(10, 15)
        random_string = generate_random_string(string_length)
        file.write(random_string + "\n")

# %%
def is_prime(number):
    if number < 2:
        return False
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            return False
    return True

with open("output10.txt", "w") as file:
    for number in range(600, 801):
        if is_prime(number):
            file.write(str(number) + "\n")

# %%
import time

# Start the timer
start_time = time.time()

# Your program or code block here
# ...

# End the timer
end_time = time.time()

# Calculate the time taken
time_taken = end_time - start_time

print("Time taken:", time_taken, "seconds")
# Out:
# Time taken: 3.790855407714844e-05 seconds

# %%
import time
import matplotlib.pyplot as plt

def sort_and_measure_time(elements):
    # Generate a list of random numbers
    lst = [random.randint(1, 1000) for _ in range(elements)]
    
    # Start the timer
    start_time = time.time()
    
    # Sort the list
    lst.sort()
    
    # End the timer
    end_time = time.time()
    
    # Calculate the time taken
    time_taken = end_time - start_time
    
    return time_taken

# Define the number of elements in the list
num_elements = [5000, 10000, 15000, 20000, 25000]

# List to store the time taken for each number of elements
time_taken_list = []

# Sort and measure time for each number of elements
for num in num_elements:
    time_taken = sort_and_measure_time(num)
    time_taken_list.append(time_taken)

# Plot the graph
plt.plot(num_elements, time_taken_list)
plt.xlabel('Number of Elements')
plt.ylabel('Time Taken (seconds)')
plt.title('Time Taken to Sort Different Numbers of Elements')
plt.show()

# %%
def calculate_average(marks):
    total = sum(marks)
    average = total / len(marks)
    return average

# Dictionary of student marks
student_marks = {
    "Alice": [80, 90, 85, 92, 88],
    "Bob": [75, 82, 88, 79, 93],
    "Charlie": [90, 85, 92, 78, 80],
    "David": [92, 88, 95, 84, 90],
    "Eve": [85, 90, 82, 87, 95]
}

# Find student with maximum average marks
max_average = float('-inf')
max_student = ""

for student, marks in student_marks.items():
    average = calculate_average(marks)
    if average > max_average:
        max_average = average
        max_student = student

# Find student with minimum average marks
min_average = float('inf')
min_student = ""

for student, marks in student_marks.items():
    average = calculate_average(marks)
    if average < min_average:
        min_average = average
        min_student = student

print("Student with maximum average marks:")
print("Name:", max_student)
print("Average Marks:", max_average)

print("\nStudent with minimum average marks:")
print("Name:", min_student)
print("Average Marks:", min_average)
# Out:
# Student with maximum average marks:
# Name: David
# Average Marks: 89.8
#
# Student with minimum average marks:
# Name: Bob
# Average Marks: 83.4
